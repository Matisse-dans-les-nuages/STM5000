# %% [markdown]
# ## MAP_STATIONS - SYGIVRE (JACTA)
# <br>
#
# #### AUTEUR : Matisse Larocque [ LARM09069805 ]
# #### VERSION : juin 2025
# ##### Dans le cadre du stage STM5000, été 2025
#
# <br>
# <br>
#
# __Notebook pour les scripts qui seront utilisés afin de déployer les données sygivre sur une carte.__
# <br><br>

# %% [markdown]
# ### IMPORTS

# %%
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray
import pandas as pd
import netCDF4
from shapely.geometry import Polygon
from matplotlib.patches import Rectangle

# %%
dsj.get_station_coord(dsj.get_all_stations()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dsj.get_station_coord(dsj.get_all_stations()[0])
#
# File ~/CODES/SCRIPTS_HQ/DATA_ACCESS_SYGIVRE_JACTA.ipynb:2, in get_all_stations()
#       1 {
# ----> 2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "1bdfddf939819b2f",
#       6    "metadata": {},
#       7    "source": [
#       8     "## DATA ACCESS - SYGIVRE (JACTA)\n",
#       9     "<br>\n",
#      10     "\n",
#      11     "#### AUTEUR : Matisse Larocque [ LARM09069805 ]\n",
#      12     "#### VERSION : mai 2025\n",
#      13     "##### Dans le cadre du stage STM5000, été 2025\n",
#      14     "\n",
#      15     "<br>\n",
#      16     "<br>\n",
#      17     "\n",
#      18     "__Notebook pour les fonctions qui seront utilisés afin de déployer les données sygivre sur une carte.__\n",
# ...
